# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
pd.DataFrame(names)
# Out:
#          0
# 0  saurabh
# 1   abdhul
# 2    rishi
# 3    nandu

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
age=[20,22,24,26]
pd.DataFrame(names,age)
# Out:
#           0
# 20  saurabh
# 22   abdhul
# 24    rishi
# 26    nandu

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
age=[20,22,24,26]
pd.DataFrame(zip(names,age))
# Out:
#          0   1
# 0  saurabh  20
# 1   abdhul  22
# 2    rishi  24
# 3    nandu  26

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
age=[20,22,24,26]
city=['jaipur','hyderabad','kolkata','nandu']
pd.DataFrame(zip(names,age,city))
# Out:
#          0   1          2
# 0  saurabh  20     jaipur
# 1   abdhul  22  hyderabad
# 2    rishi  24    kolkata
# 3    nandu  26      nandu

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
age=[20,22,24,26]
city=['jaipur','hyderabad','kolkata','nandu']
data=zip(names,age,city)
pd.DataFrame(data)
# Out:
#          0   1          2
# 0  saurabh  20     jaipur
# 1   abdhul  22  hyderabad
# 2    rishi  24    kolkata
# 3    nandu  26      nandu

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
age=[20,22,24,26]
city=['jaipur','hyderabad','kolkata','nandu']
data=zip(names,age,city)
df=pd.DataFrame(data)
df
# Out:
#          0   1          2
# 0  saurabh  20     jaipur
# 1   abdhul  22  hyderabad
# 2    rishi  24    kolkata
# 3    nandu  26      nandu

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
age=[20,22,24,26]
city=['jaipur','hyderabad','kolkata','nandu']
data=zip(names,age,city)
cols=['Names','Age','City']
df=pd.DataFrame(data,columns=cols)
df
# Out:
#      Names  Age       City
# 0  saurabh   20     jaipur
# 1   abdhul   22  hyderabad
# 2    rishi   24    kolkata
# 3    nandu   26      nandu

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
age=[20,22,24,26]
city=['jaipur','hyderabad','kolkata','nandu']
data=zip(names,age,city)
cols=['Names','Age','City']
id=['A','B','C','D']
df=pd.DataFrame(data,
                index=id,
                columns=cols)
df
# Out:
#      Names  Age       City
# A  saurabh   20     jaipur
# B   abdhul   22  hyderabad
# C    rishi   24    kolkata
# D    nandu   26      nandu

# %%
import pandas as pd
names=['saurabh','abdhul','rishi','nandu']
age=[20,22,24,26]
city=['jaipur','hyderabad','kolkata','blr']
data=zip(names,age,)
cols=['Names','Age']
df=pd.DataFrame(data,
                index=city,
                columns=cols)
df
# Out:
#              Names  Age
# jaipur     saurabh   20
# hyderabad   abdhul   22
# kolkata      rishi   24
# blr          nandu   26

# %%
import pandas as pd
dict1={'names':['saurabh','abdhul','rishi','nandu'],
        'age':[20,22,24,26],
        'city':['jaipur','hyderabad','kolkata','bangalore']}
pd.DataFrame(dict1)
# Out:
#      names  age       city
# 0  saurabh   20     jaipur
# 1   abdhul   22  hyderabad
# 2    rishi   24    kolkata
# 3    nandu   26  bangalore

# %%
import pandas as pd
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
df1['Names']=['saurabh','abdhul','rishi','nandu']
df1['Age']=[20,22,24,26]
df1['City']=['jaipur','hyderabad','kolkata','bangalore']
df1
# Out:
#      Names  Age       City
# 0  saurabh   20     jaipur
# 1   abdhul   22  hyderabad
# 2    rishi   24    kolkata
# 3    nandu   26  bangalore

# %%
df
# Out:
#              Names  Age
# jaipur     saurabh   20
# hyderabad   abdhul   22
# kolkata      rishi   24
# blr          nandu   26

# %%
df1
# Out:
#      Names  Age       City
# 0  saurabh   20     jaipur
# 1   abdhul   22  hyderabad
# 2    rishi   24    kolkata
# 3    nandu   26  bangalore

# %%
df
# Out:
#              Names  Age
# jaipur     saurabh   20
# hyderabad   abdhul   22
# kolkata      rishi   24
# blr          nandu   26
